# %%
import numpy as np
import os

from keras.models import Sequential
from keras.layers import Dense, Conv2D
from keras.layers import Dropout
from keras.layers import Flatten,Activation
from keras.constraints import maxnorm
from tensorflow.keras.optimizers import Adam

from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping


from keras.utils import np_utils
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
x_train = ImageDataGenerator(rescale=1/255)
x_test = ImageDataGenerator(rescale=1/255)

# %%
x_train_data = x_train.flow_from_directory(
    directory=r"/content/drive/MyDrive/x_ray detect/train",
    target_size=(350, 350),
    batch_size=3,
    class_mode='categorical',
    )
x_test_data = x_test.flow_from_directory(
    directory=r"/content/drive/MyDrive/x_ray detect/test",
    target_size=(350, 350),
    batch_size=3,
    class_mode= "categorical",
    )
# Out:
# Found 2468 images belonging to 2 classes.
# Found 652 images belonging to 2 classes.

# %%
x_train_data.class_indices
# Out:
# {'cancer': 0, 'normal': 1}

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dense, Flatten,Activation,BatchNormalization,Dropout
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()

model.add(Conv2D(filters = 256, kernel_size = (3,3),padding = 'Same',activation ='relu', input_shape = (350,350,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(16, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dropout(0.5))
model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dropout(0.5))

model.add(Activation('relu'))
model.add(Dense(2, activation = "softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 350, 350, 256)     7168
#
#  activation (Activation)     (None, 350, 350, 256)     0
#
#  max_pooling2d (MaxPooling2D  (None, 175, 175, 256)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 175, 175, 64)      147520
#
#  activation_1 (Activation)   (None, 175, 175, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 88, 88, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 88, 88, 16)        9232
#
#  activation_2 (Activation)   (None, 88, 88, 16)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 44, 44, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dropout (Dropout)           (None, 30976)             0
#
#  dense (Dense)               (None, 64)                1982528
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 2,146,578
# Trainable params: 2,146,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.backend import categorical_crossentropy
from tensorflow.keras.optimizers import Adam,SGD

from tensorflow.keras.optimizers import SGD
#opt = SGD(lr = 0.01, momentum= 0.9)
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
history=model.fit(x_train_data,
                  epochs=10,
                  batch_size=32,
                  verbose=1,
                  validation_data= x_test_data)
# Out:
# Epoch 1/10
# 823/823 [==============================] - 124s 143ms/step - loss: 0.2465 - accuracy: 0.9267 - val_loss: 0.2496 - val_accuracy: 0.9064
# Epoch 2/10
# 823/823 [==============================] - 68s 83ms/step - loss: 0.1741 - accuracy: 0.9522 - val_loss: 0.2047 - val_accuracy: 0.9233
# Epoch 3/10
# 823/823 [==============================] - 69s 84ms/step - loss: 0.1183 - accuracy: 0.9672 - val_loss: 0.2277 - val_accuracy: 0.9294
# Epoch 4/10
# 823/823 [==============================] - 68s 83ms/step - loss: 0.1352 - accuracy: 0.9684 - val_loss: 0.2907 - val_accuracy: 0.9264
# Epoch 5/10
# 823/823 [==============================] - 68s 83ms/step - loss: 0.1707 - accuracy: 0.9595 - val_loss: 0.2098 - val_accuracy: 0.9279
# Epoch 6/10
# 823/823 [==============================] - 68s 83ms/step - loss: 0.1008 - accuracy: 0.9733 - val_loss: 0.1949 - val_accuracy: 0.9264
# Epoch 7/10
# 823/823 [==============================] - 69s 83ms/step - loss: 0.0764 - accuracy: 0.9745 - val_loss: 0.2031 - val_accuracy: 0.9248
# Epoch 8/10
# 823/823 [==============================] - 69s 83ms/step - loss: 0.0826 - accuracy: 0.9785 - val_loss: 0.2326 - val_accuracy: 0.9049
# Epoch 9/10
# 823/823 [==============================] - 69s 84ms/step - loss: 0.0614 - accuracy: 0.9810 - val_loss: 0.2883 - val_accuracy: 0.9279
# Epoch 10/10
# 823/823 [==============================] - 68s 83ms/step - loss: 0.0435 - accuracy: 0.9866 - val_loss: 0.3657 - val_accuracy: 0.9156

# %%
model.save('lung_detect.h5')

# %%
import matplotlib.pyplot as plt 
plt.plot(history.history['val_accuracy'])
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['validation','train'], loc='upper-left')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Unrecognized location 'upper-left'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   import sys

# %%
import numpy as np
from numpy import argmax
from keras.saving.save import load_model
model5=load_model('lung_detect.h5')
from keras.preprocessing.image import load_img, img_to_array
labels = {0:'cancer',
          1:'normal',
         }
img=load_img('/content/drive/MyDrive/x_ray detect/test/cancer/e13092b1a2848a29558f6c661652332d.jpg', target_size=(350,350)) #filename: link hinh anh
plt.imshow(img)
img=img_to_array(img)
img = img.reshape(1,350,350,3)
img=img.astype('float32')
img=img/255
img.shape
np.argmax(model5.predict(img),axis=1)
print('expectation:',labels[np.argmax(model5.predict(img))])
print('với độ chính xác:',int(np.max(history.history['val_accuracy'])*100),'%')
print(history.history['val_accuracy'])
# Out:
# expectation: cancer
# với độ chính xác: 92 %
# [0.9064416885375977, 0.9233129024505615, 0.9294478297233582, 0.9263803958892822, 0.9279140830039978, 0.9263803958892822, 0.9248466491699219, 0.9049080014228821, 0.9279140830039978, 0.9156441688537598]
